# %% [markdown]
# # Kidney Stone Classication using CT_Images

# %% [markdown]
# ## Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
import random
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import cv2 
from skimage.feature import hog 
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix
# import gradio as gr
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# !pip install keras==3.6.0
# Out:
# Collecting keras==3.6.0
#   Obtaining dependency information for keras==3.6.0 from https://files.pythonhosted.org/packages/c2/88/eef50051a772dcb4433d1f3e4c1d6576ba450fe83e89d028d7e8b85a2122/keras-3.6.0-py3-none-any.whl.metadata
#   Using cached keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (2.1.0)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (1.24.3)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (13.7.0)
# Requirement already satisfied: namex in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.0.8)
# Requirement already satisfied: h5py in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (3.12.1)
# Requirement already satisfied: optree in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.4.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (23.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\dell\anaconda3\lib\site-packages (from optree->keras==3.6.0) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras==3.6.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras==3.6.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.6.0) (0.1.0)
# Using cached keras-3.6.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
# Successfully installed keras-3.6.0

# %%
# !pip install tensorflow

# %% [markdown]
# ## Preparing Traning Data

# %%
folder_path = "../../CT scan kidnet stone detection code/CT_Images/Train"
filenames = []
categories = []

for category in os.listdir(folder_path):
    category_path = os.path.join(folder_path, category)
    
    if os.path.isdir(category_path):
        for filename in os.listdir(category_path):
            filenames.append(os.path.join(category, filename))
            categories.append(category)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#                     filename category
# 0     Normal\Normal- (1).jpg   Normal
# 1    Normal\Normal- (10).jpg   Normal
# 2   Normal\Normal- (100).jpg   Normal
# 3  Normal\Normal- (1000).jpg   Normal
# 4   Normal\Normal- (101).jpg   Normal

# %%
df.tail()
# Out:
#                     filename category
# 2995  Stone\Stone- (995).jpg    Stone
# 2996  Stone\Stone- (996).jpg    Stone
# 2997  Stone\Stone- (997).jpg    Stone
# 2998  Stone\Stone- (998).jpg    Stone
# 2999  Stone\Stone- (999).jpg    Stone

# %%
df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# We have 3000 total images (2000 Normal, 1000 Stone)

# %% [markdown]
# ## Visualizing Data

# %%
sample = random.choice(filenames)
image = load_img("../../CT scan kidnet stone detection code/CT_Images/Train/"+sample)
plt.imshow(image)

# %% [markdown]
# # CNN(Convolutional Neural Network)

# %% [markdown]
# ## Building CNN Model

# %%
model = Sequential()

#Adding convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#Adding a second convolutional layer
model.add(Conv2D(64, (3, 3) , activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=( 2, 2)))


model.add(Flatten())  # this converts our feature maps to 1D feature vectors
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2)) # as we have binary class i.e stone and normal so value is 2
model.add(Activation('sigmoid')) #sigmoid for binary class classification
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 198, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 198, 198, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 99, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 97, 97, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 97, 97, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 48, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 147456)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      18,874,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 2)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,895,042 (72.08 MB)
#  Trainable params: 18,894,594 (72.08 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Call Backs

# %% [markdown]
# #### Early Stop
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# #### Learning Rate Reduction
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ### Preparing Data

# %%
train_df, validate_df = train_test_split(df, test_size=0.10, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Train and Validation generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(200,200),
    class_mode='categorical',
    batch_size=15,
    shuffle=True
)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(200,200),
    class_mode='categorical',
    batch_size=15
)
# Out:
# Found 2700 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.

# %%
# Function to yield data from the generator
def generate_data(generator):
    while True:
        yield from generator

# Create TensorFlow datasets with repeat
train_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(train_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 200, 200, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()  # Repeat indefinitely

validation_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(validation_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 200, 200, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()

# %% [markdown]
# ### Visulaizing the output of data gen

# %%
example_df = train_df.sample(n=5).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(200,200),
    class_mode='categorical',
)
# Out:
# Found 5 validated image filenames belonging to 2 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fitting the Model

# %%
# Compiling the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_dataset, 
    epochs=50,
    validation_data=validation_dataset,
    validation_steps=validate_df.shape[0]//15,
    steps_per_epoch=train_df.shape[0]//15,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.6950 - loss: 0.6880 - val_accuracy: 0.3100 - val_loss: 3.3058 - learning_rate: 0.0010
# Epoch 2/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 148s 825ms/step - accuracy: 0.8175 - loss: 0.4294 - val_accuracy: 0.3100 - val_loss: 3.1876 - learning_rate: 0.0010
# Epoch 3/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 127s 704ms/step - accuracy: 0.8592 - loss: 0.3522 - val_accuracy: 0.8267 - val_loss: 0.5256 - learning_rate: 0.0010
# Epoch 4/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 128s 709ms/step - accuracy: 0.8860 - loss: 0.2967 - val_accuracy: 0.7967 - val_loss: 0.6118 - learning_rate: 0.0010
# Epoch 5/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 130s 719ms/step - accuracy: 0.8673 - loss: 0.3100 - val_accuracy: 0.8800 - val_loss: 0.3335 - learning_rate: 0.0010
# Epoch 6/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 136s 753ms/step - accuracy: 0.8840 - loss: 0.2794 - val_accuracy: 0.8600 - val_loss: 0.4092 - learning_rate: 0.0010
# Epoch 7/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.8915 - loss: 0.2470
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 134s 746ms/step - accuracy: 0.8914 - loss: 0.2471 - val_accuracy: 0.8367 - val_loss: 0.4858 - learning_rate: 0.0010
# Epoch 8/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 127s 704ms/step - accuracy: 0.9081 - loss: 0.2401 - val_accuracy: 0.9300 - val_loss: 0.1500 - learning_rate: 5.0000e-04
# Epoch 9/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 124s 686ms/step - accuracy: 0.9247 - loss: 0.2128 - val_accuracy: 0.9067 - val_loss: 0.2064 - learning_rate: 5.0000e-04
# Epoch 10/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 123s 684ms/step - accuracy: 0.9308 - loss: 0.1960 - val_accuracy: 0.9433 - val_loss: 0.1222 - learning_rate: 5.0000e-04
# Epoch 11/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 132s 734ms/step - accuracy: 0.9182 - loss: 0.2119 - val_accuracy: 0.8033 - val_loss: 0.9377 - learning_rate: 5.0000e-04
# Epoch 12/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9140 - loss: 0.2266
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 134s 741ms/step - accuracy: 0.9141 - loss: 0.2265 - val_accuracy: 0.9167 - val_loss: 0.1739 - learning_rate: 5.0000e-04
# Epoch 13/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 130s 725ms/step - accuracy: 0.9140 - loss: 0.1957 - val_accuracy: 0.9533 - val_loss: 0.1258 - learning_rate: 2.5000e-04
# Epoch 14/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 131s 730ms/step - accuracy: 0.9338 - loss: 0.1693 - val_accuracy: 0.9400 - val_loss: 0.1402 - learning_rate: 2.5000e-04
# Epoch 15/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.9436 - loss: 0.1514
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 127s 707ms/step - accuracy: 0.9436 - loss: 0.1514 - val_accuracy: 0.9433 - val_loss: 0.1170 - learning_rate: 2.5000e-04
# Epoch 16/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 129s 717ms/step - accuracy: 0.9468 - loss: 0.1462 - val_accuracy: 0.9800 - val_loss: 0.0665 - learning_rate: 1.2500e-04
# Epoch 17/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 126s 700ms/step - accuracy: 0.9444 - loss: 0.1468 - val_accuracy: 0.9333 - val_loss: 0.1278 - learning_rate: 1.2500e-04
# Epoch 18/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.9408 - loss: 0.1440
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 132s 733ms/step - accuracy: 0.9408 - loss: 0.1439 - val_accuracy: 0.9167 - val_loss: 0.1833 - learning_rate: 1.2500e-04
# Epoch 19/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 129s 718ms/step - accuracy: 0.9459 - loss: 0.1324 - val_accuracy: 0.8967 - val_loss: 0.1995 - learning_rate: 6.2500e-05
# Epoch 20/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9452 - loss: 0.1393
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 128s 711ms/step - accuracy: 0.9452 - loss: 0.1393 - val_accuracy: 0.9567 - val_loss: 0.0980 - learning_rate: 6.2500e-05
# Epoch 21/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 127s 705ms/step - accuracy: 0.9443 - loss: 0.1431 - val_accuracy: 0.9733 - val_loss: 0.0814 - learning_rate: 3.1250e-05
# Epoch 22/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.9558 - loss: 0.1219
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 127s 707ms/step - accuracy: 0.9558 - loss: 0.1219 - val_accuracy: 0.9400 - val_loss: 0.1267 - learning_rate: 3.1250e-05
# Epoch 23/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 127s 702ms/step - accuracy: 0.9498 - loss: 0.1413 - val_accuracy: 0.9500 - val_loss: 0.1110 - learning_rate: 1.5625e-05
# Epoch 24/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.9532 - loss: 0.1335
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-05.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 126s 702ms/step - accuracy: 0.9532 - loss: 0.1335 - val_accuracy: 0.9500 - val_loss: 0.1004 - learning_rate: 1.5625e-05
# Epoch 25/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 126s 702ms/step - accuracy: 0.9505 - loss: 0.1265 - val_accuracy: 0.9500 - val_loss: 0.1107 - learning_rate: 1.0000e-05
# Epoch 26/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 124s 691ms/step - accuracy: 0.9461 - loss: 0.1254 - val_accuracy: 0.9500 - val_loss: 0.1215 - learning_rate: 1.0000e-05

# %% [markdown]
# ### Visualizing the Training history

# %%
# Plotting the training history
plt.figure(figsize=(12, 8)) 

# Plot training & validation accuracy values
plt.subplot(2, 1, 1)  # 2 rows, 1 column, first subplot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second subplot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving the CNN Model

# %%
# Saving the Model
model.save('0.1_kidney_stone_detection_CT_image_model_200.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Testing Data

# %%
test_folder_path = "../../CT scan kidnet stone detection code/CT_Images/Test"
test_filenames = []
test_categories = []

for category in os.listdir(test_folder_path):
    test_category_path = os.path.join(test_folder_path, category)
    
    if os.path.isdir(test_category_path):
        for filename in os.listdir(test_category_path):
            test_filenames.append(os.path.join(category, filename))
            test_categories.append(category)

test_df = pd.DataFrame({
    'filename': test_filenames,
    'category': test_categories
})

# %%
test_gen = ImageDataGenerator(rescale=1./255)

test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Test/", 
    x_col='filename',
    y_col='category',
    target_size=(200,200),
    class_mode='categorical',
    batch_size=15,
    shuffle=False
)
# Out:
# Found 900 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Predictions

# %%
steps = int(np.ceil(test_df.shape[0] / 15))

predict = model.predict(test_generator, steps=steps)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step

# %%
test_df['predicted category'] = np.argmax(predict, axis=-1)

# %%
test_df['predicted category'] = test_df['predicted category'].replace({ 1: 'Stone', 0: 'Normal' })

# %%
test_df.head()
# Out:
#                     filename category predicted category
# 0  Normal\Normal- (1001).jpg   Normal             Normal
# 1  Normal\Normal- (1002).jpg   Normal             Normal
# 2  Normal\Normal- (1003).jpg   Normal             Normal
# 3  Normal\Normal- (1004).jpg   Normal             Normal
# 4  Normal\Normal- (1005).jpg   Normal             Normal

# %%
plt.figure(figsize=(12, 4))

# Plot the first bar plot (predicted category)
plt.subplot(1, 2, 1)
test_df['predicted category'].value_counts().plot.bar()
plt.title('Predicted Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Plot the second bar plot (actual category)
plt.subplot(1, 2, 2)
test_df['category'].value_counts().plot.bar()
plt.title('Actual Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Assuming 'Stone' is the positive class
print('Precision:', precision_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print('Recall:', recall_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print('F1 Score:', f1_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print(classification_report(test_df['category'], test_df['predicted category']))
# Out:
# Precision: 0.9945945945945946
# Recall: 0.6133333333333333
# F1 Score: 0.7587628865979381
#               precision    recall  f1-score   support
#
#       Normal       0.84      1.00      0.91       600
#        Stone       0.99      0.61      0.76       300
#
#     accuracy                           0.87       900
#    macro avg       0.92      0.81      0.83       900
# weighted avg       0.89      0.87      0.86       900

# %%
cm = confusion_matrix(test_df['category'], test_df['predicted category'])

sns.heatmap(cm, annot=True, fmt='d', cmap='BuPu')

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

plt.show()

# %% [markdown]
# The results is baised toward normal as we have more Normal Images

# %%
model.evaluate(test_generator)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 201ms/step - accuracy: 0.9793 - loss: 0.0402
# [0.29489701986312866, 0.8700000047683716]

# %% [markdown]
# # Prediction with user input

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import random

# %%
model = load_model('0.3_kidney_stone_detection_CT_image_model_200.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_image(image_path):
    """
    Predicts if a CT scan image is 'Normal' or 'Stone'.
    
    Parameters:
    - image_path (str): Path to the CT scan image.
    
    Returns:
    - str: 'Normal' or 'Stone' based on the prediction.
    """
    # Load and preprocess the image
    image = load_img(image_path, target_size=(200, 200))  # Resize to match model's input size
    image = img_to_array(image) / 255.0  # Normalize the image
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    
    # Make a prediction
    prediction = model.predict(image)
    print(prediction[0][0])
    #   [0][0]= no stone prob  [0][1]= stone prob
    if prediction[0][1] > 0.5:
        return 'Kidney Stone Detected (Positive)',round(prediction[0][0]*100,2),'%'
    else:
        return 'No Kidney Stone Detected  (Negative)',round(prediction[0][0]*100,2),'%'

# %%
user_image_path = input("Enter the path to your CT scan image: ")
if os.path.exists(user_image_path):
    result = predict_image(user_image_path)
    print(f"The uploaded CT scan image is classified as: {result}")
else:
    print("File not found. Please check the path and try again.")
# Out:
# Enter the path to your CT scan image: C:\Users\Dell\Downloads\brain.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 0.25007522
# The uploaded CT scan image is classified as: ('No Kidney Stone Detected  (Negative)', 25.01, '%')
