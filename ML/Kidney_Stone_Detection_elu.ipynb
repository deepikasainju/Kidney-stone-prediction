# %% [markdown]
# # Kidney Stone Classication using CT_Images

# %% [markdown]
# ## Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
import random
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import cv2 
from skimage.feature import hog 
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix
# import gradio as gr

# %%
# !pip install keras==3.6.0
# Out:
# Collecting keras==3.6.0
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (2.1.0)
# Requirement already satisfied: numpy in c:\users\binisha\desktop\ml\env\lib\site-packages (from keras==3.6.0) (1.26.4)
# Requirement already satisfied: rich in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (13.9.4)
# Requirement already satisfied: namex in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (0.0.8)
# Requirement already satisfied: h5py in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (3.12.1)
# Requirement already satisfied: optree in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (0.4.1)
# Requirement already satisfied: packaging in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras==3.6.0) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from optree->keras==3.6.0) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from rich->keras==3.6.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from rich->keras==3.6.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.6.0) (0.1.2)
# Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.7.0
#     Uninstalling keras-3.7.0:
#       Successfully uninstalled keras-3.7.0
# Successfully installed keras-3.6.0

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\binisha\appdata\roaming\python\python312\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.6.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\binisha\desktop\ml\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\binisha\desktop\ml\env\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\binisha\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.25.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\binisha\desktop\ml\env\lib\site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.2 in c:\users\binisha\desktop\ml\env\lib\site-packages (from scikit-image) (1.13.1)
# Collecting networkx>=3.0 (from scikit-image)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pillow>=10.1 in c:\users\binisha\desktop\ml\env\lib\site-packages (from scikit-image) (10.4.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2025.1.10-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in c:\users\binisha\appdata\roaming\python\python312\site-packages (from scikit-image) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.25.0-cp312-cp312-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 2.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/12.9 MB 3.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.9 MB 3.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.9 MB 4.1 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.9 MB 3.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.2/12.9 MB 4.1 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.9 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 7.1/12.9 MB 4.2 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.9 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/12.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 10.0/12.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.9 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 4.3 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------ --- 1.6/1.7 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.7 MB/s eta 0:00:00
# Downloading tifffile-2025.1.10-py3-none-any.whl (227 kB)
# Installing collected packages: tifffile, networkx, lazy-loader, imageio, scikit-image
# Successfully installed imageio-2.37.0 lazy-loader-0.4 networkx-3.4.2 scikit-image-0.25.0 tifffile-2025.1.10
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Preparing Traning Data

# %%
folder_path = "CT_Images/Train"
filenames = []
categories = []

for category in os.listdir(folder_path):
    category_path = os.path.join(folder_path, category)
    
    if os.path.isdir(category_path):
        for filename in os.listdir(category_path):
            filenames.append(os.path.join(category, filename))
            categories.append(category)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#                     filename category
# 0     Normal\Normal- (1).jpg   Normal
# 1    Normal\Normal- (10).jpg   Normal
# 2   Normal\Normal- (100).jpg   Normal
# 3  Normal\Normal- (1000).jpg   Normal
# 4   Normal\Normal- (101).jpg   Normal

# %%
df.tail()
# Out:
#                     filename category
# 2995  Stone\Stone- (995).jpg    Stone
# 2996  Stone\Stone- (996).jpg    Stone
# 2997  Stone\Stone- (997).jpg    Stone
# 2998  Stone\Stone- (998).jpg    Stone
# 2999  Stone\Stone- (999).jpg    Stone

# %%
df['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# We have 3000 total images (2000 Normal, 1000 Stone)

# %% [markdown]
# ## Visualizing Data

# %%
sample = random.choice(filenames)
image = load_img("CT_Images/Train/"+sample)
plt.imshow(image)

# %% [markdown]
# # CNN(Convolutional Neural Network)

# %% [markdown]
# ## Building CNN Model

# %%
model = Sequential()

#Adding convolutional layers
model.add(Conv2D(32, (3, 3), activation='elu', input_shape=(150, 150, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#Adding a second convolutional layer
model.add(Conv2D(64, (3, 3) , activation='elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())  # this converts our feature maps to 1D feature vectors
model.add(Dense(128, activation='elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2)) # as we have binary class i.e stone and normal so value is 2
model.add(Activation('sigmoid')) #sigmoid for binary class classification
# Out:
# C:\Users\Binisha\Desktop\ml\env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 148, 148, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 72, 72, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 82944)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │      10,616,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 2)                   │             258 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 2)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,637,506 (40.58 MB)
#  Trainable params: 10,637,058 (40.58 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Call Backs

# %% [markdown]
# #### Early Stop
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# #### Learning Rate Reduction
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ### Preparing Data

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# ### Train and Validation generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15,
    shuffle=True
)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15
)
# Out:
# Found 2400 validated image filenames belonging to 2 classes.
# Found 600 validated image filenames belonging to 2 classes.

# %%
# Function to yield data from the generator
def generate_data(generator):
    while True:
        yield from generator

# Create TensorFlow datasets with repeat
train_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(train_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 150, 150, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()  # Repeat indefinitely

validation_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(validation_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 150, 150, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()

# %% [markdown]
# ### Visulaizing the output of data gen

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fitting the Model

# %%
# Compiling the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_dataset, 
    epochs=50,
    validation_data=validation_dataset,
    validation_steps=validate_df.shape[0]//15,
    steps_per_epoch=train_df.shape[0]//15,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 158s 955ms/step - accuracy: 0.6674 - loss: 0.7885 - val_accuracy: 0.3100 - val_loss: 1.8581 - learning_rate: 0.0010
# Epoch 2/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 112s 697ms/step - accuracy: 0.7918 - loss: 0.4803 - val_accuracy: 0.3100 - val_loss: 3.4929 - learning_rate: 0.0010
# Epoch 3/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.8320 - loss: 0.3966
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 106s 662ms/step - accuracy: 0.8320 - loss: 0.3966 - val_accuracy: 0.3100 - val_loss: 4.0000 - learning_rate: 0.0010
# Epoch 4/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 123s 768ms/step - accuracy: 0.8685 - loss: 0.3266 - val_accuracy: 0.7417 - val_loss: 0.4918 - learning_rate: 5.0000e-04
# Epoch 5/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 100s 623ms/step - accuracy: 0.8735 - loss: 0.2981 - val_accuracy: 0.9217 - val_loss: 0.1605 - learning_rate: 5.0000e-04
# Epoch 6/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 105s 658ms/step - accuracy: 0.8741 - loss: 0.3042 - val_accuracy: 0.7633 - val_loss: 1.1997 - learning_rate: 5.0000e-04
# Epoch 7/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 643ms/step - accuracy: 0.8850 - loss: 0.2759
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 106s 663ms/step - accuracy: 0.8851 - loss: 0.2759 - val_accuracy: 0.5500 - val_loss: 1.3709 - learning_rate: 5.0000e-04
# Epoch 8/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 102s 640ms/step - accuracy: 0.8988 - loss: 0.2644 - val_accuracy: 0.9283 - val_loss: 0.1757 - learning_rate: 2.5000e-04
# Epoch 9/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 488ms/step - accuracy: 0.9058 - loss: 0.2352 - val_accuracy: 0.8267 - val_loss: 0.7328 - learning_rate: 2.5000e-04
# Epoch 10/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 489ms/step - accuracy: 0.9235 - loss: 0.1954 - val_accuracy: 0.9783 - val_loss: 0.0869 - learning_rate: 2.5000e-04
# Epoch 11/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 79s 492ms/step - accuracy: 0.9218 - loss: 0.2039 - val_accuracy: 0.9550 - val_loss: 0.0964 - learning_rate: 2.5000e-04
# Epoch 12/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9103 - loss: 0.2233
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 485ms/step - accuracy: 0.9103 - loss: 0.2232 - val_accuracy: 0.9367 - val_loss: 0.1181 - learning_rate: 2.5000e-04
# Epoch 13/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 488ms/step - accuracy: 0.9305 - loss: 0.1890 - val_accuracy: 0.9850 - val_loss: 0.0709 - learning_rate: 1.2500e-04
# Epoch 14/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 80s 503ms/step - accuracy: 0.9291 - loss: 0.1895 - val_accuracy: 0.9483 - val_loss: 0.0952 - learning_rate: 1.2500e-04
# Epoch 15/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9305 - loss: 0.1818
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 468ms/step - accuracy: 0.9305 - loss: 0.1818 - val_accuracy: 0.9633 - val_loss: 0.0827 - learning_rate: 1.2500e-04
# Epoch 16/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 464ms/step - accuracy: 0.9329 - loss: 0.1672 - val_accuracy: 0.9900 - val_loss: 0.0554 - learning_rate: 6.2500e-05
# Epoch 17/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 463ms/step - accuracy: 0.9300 - loss: 0.1826 - val_accuracy: 0.9850 - val_loss: 0.0536 - learning_rate: 6.2500e-05
# Epoch 18/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 461ms/step - accuracy: 0.9277 - loss: 0.1822 - val_accuracy: 0.9917 - val_loss: 0.0519 - learning_rate: 6.2500e-05
# Epoch 19/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 467ms/step - accuracy: 0.9419 - loss: 0.1572 - val_accuracy: 0.7050 - val_loss: 0.5839 - learning_rate: 6.2500e-05
# Epoch 20/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9303 - loss: 0.1828
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 80s 503ms/step - accuracy: 0.9304 - loss: 0.1827 - val_accuracy: 0.9833 - val_loss: 0.0575 - learning_rate: 6.2500e-05
# Epoch 21/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 81s 507ms/step - accuracy: 0.9387 - loss: 0.1459 - val_accuracy: 0.9917 - val_loss: 0.0535 - learning_rate: 3.1250e-05
# Epoch 22/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9460 - loss: 0.1515
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 77s 479ms/step - accuracy: 0.9461 - loss: 0.1514 - val_accuracy: 0.9783 - val_loss: 0.0589 - learning_rate: 3.1250e-05
# Epoch 23/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 476ms/step - accuracy: 0.9499 - loss: 0.1412 - val_accuracy: 0.9933 - val_loss: 0.0449 - learning_rate: 1.5625e-05
# Epoch 24/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 77s 481ms/step - accuracy: 0.9486 - loss: 0.1411 - val_accuracy: 0.9950 - val_loss: 0.0423 - learning_rate: 1.5625e-05
# Epoch 25/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 473ms/step - accuracy: 0.9448 - loss: 0.1397 - val_accuracy: 0.9900 - val_loss: 0.0495 - learning_rate: 1.5625e-05
# Epoch 26/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9457 - loss: 0.1411
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 81s 506ms/step - accuracy: 0.9456 - loss: 0.1412 - val_accuracy: 0.9933 - val_loss: 0.0440 - learning_rate: 1.5625e-05
# Epoch 27/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 90s 565ms/step - accuracy: 0.9360 - loss: 0.1504 - val_accuracy: 0.9950 - val_loss: 0.0398 - learning_rate: 1.0000e-05
# Epoch 28/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 105s 655ms/step - accuracy: 0.9511 - loss: 0.1433 - val_accuracy: 0.9917 - val_loss: 0.0467 - learning_rate: 1.0000e-05
# Epoch 29/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 117s 733ms/step - accuracy: 0.9467 - loss: 0.1552 - val_accuracy: 0.9933 - val_loss: 0.0420 - learning_rate: 1.0000e-05
# Epoch 30/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 104s 649ms/step - accuracy: 0.9475 - loss: 0.1354 - val_accuracy: 0.9917 - val_loss: 0.0453 - learning_rate: 1.0000e-05
# Epoch 31/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 91s 568ms/step - accuracy: 0.9430 - loss: 0.1480 - val_accuracy: 0.9950 - val_loss: 0.0407 - learning_rate: 1.0000e-05
# Epoch 32/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 94s 591ms/step - accuracy: 0.9384 - loss: 0.1611 - val_accuracy: 0.9950 - val_loss: 0.0387 - learning_rate: 1.0000e-05
# Epoch 33/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 117s 732ms/step - accuracy: 0.9377 - loss: 0.1534 - val_accuracy: 0.9950 - val_loss: 0.0402 - learning_rate: 1.0000e-05
# Epoch 34/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 94s 589ms/step - accuracy: 0.9475 - loss: 0.1357 - val_accuracy: 0.9950 - val_loss: 0.0401 - learning_rate: 1.0000e-05
# Epoch 35/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 108s 677ms/step - accuracy: 0.9605 - loss: 0.1241 - val_accuracy: 0.9933 - val_loss: 0.0387 - learning_rate: 1.0000e-05
# Epoch 36/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 115s 716ms/step - accuracy: 0.9521 - loss: 0.1481 - val_accuracy: 0.9950 - val_loss: 0.0399 - learning_rate: 1.0000e-05
# Epoch 37/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 98s 611ms/step - accuracy: 0.9452 - loss: 0.1525 - val_accuracy: 0.9917 - val_loss: 0.0380 - learning_rate: 1.0000e-05
# Epoch 38/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 106s 665ms/step - accuracy: 0.9475 - loss: 0.1651 - val_accuracy: 0.9967 - val_loss: 0.0374 - learning_rate: 1.0000e-05
# Epoch 39/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 111s 691ms/step - accuracy: 0.9479 - loss: 0.1394 - val_accuracy: 0.9950 - val_loss: 0.0369 - learning_rate: 1.0000e-05
# Epoch 40/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 100s 623ms/step - accuracy: 0.9490 - loss: 0.1483 - val_accuracy: 0.9950 - val_loss: 0.0384 - learning_rate: 1.0000e-05
# Epoch 41/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 97s 609ms/step - accuracy: 0.9531 - loss: 0.1306 - val_accuracy: 0.9950 - val_loss: 0.0371 - learning_rate: 1.0000e-05
# Epoch 42/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 84s 528ms/step - accuracy: 0.9518 - loss: 0.1319 - val_accuracy: 0.9950 - val_loss: 0.0361 - learning_rate: 1.0000e-05
# Epoch 43/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 80s 500ms/step - accuracy: 0.9486 - loss: 0.1489 - val_accuracy: 0.9950 - val_loss: 0.0348 - learning_rate: 1.0000e-05
# Epoch 44/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 82s 511ms/step - accuracy: 0.9543 - loss: 0.1227 - val_accuracy: 0.9950 - val_loss: 0.0363 - learning_rate: 1.0000e-05
# Epoch 45/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 488ms/step - accuracy: 0.9510 - loss: 0.1359 - val_accuracy: 0.9933 - val_loss: 0.0363 - learning_rate: 1.0000e-05
# Epoch 46/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 489ms/step - accuracy: 0.9463 - loss: 0.1502 - val_accuracy: 0.9933 - val_loss: 0.0371 - learning_rate: 1.0000e-05
# Epoch 47/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 490ms/step - accuracy: 0.9481 - loss: 0.1294 - val_accuracy: 0.9950 - val_loss: 0.0355 - learning_rate: 1.0000e-05
# Epoch 48/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 489ms/step - accuracy: 0.9526 - loss: 0.1300 - val_accuracy: 0.9917 - val_loss: 0.0375 - learning_rate: 1.0000e-05
# Epoch 49/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 465ms/step - accuracy: 0.9356 - loss: 0.1510 - val_accuracy: 0.9950 - val_loss: 0.0345 - learning_rate: 1.0000e-05
# Epoch 50/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 462ms/step - accuracy: 0.9561 - loss: 0.1214 - val_accuracy: 0.9967 - val_loss: 0.0342 - learning_rate: 1.0000e-05

# %% [markdown]
# ### Visualizing the Training history

# %%
# Plotting the training history
plt.figure(figsize=(12, 8)) 

# Plot training & validation accuracy values
plt.subplot(2, 1, 1)  # 2 rows, 1 column, first subplot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second subplot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving the CNN Model

# %%
# Saving the Model
model.save('kidney_stone_detection_CT_image_model_elu.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Testing Data

# %%
test_folder_path = "CT_Images/Test"
test_filenames = []
test_categories = []

for category in os.listdir(test_folder_path):
    test_category_path = os.path.join(test_folder_path, category)
    
    if os.path.isdir(test_category_path):
        for filename in os.listdir(test_category_path):
            test_filenames.append(os.path.join(category, filename))
            test_categories.append(category)

test_df = pd.DataFrame({
    'filename': test_filenames,
    'category': test_categories
})

# %%
test_gen = ImageDataGenerator(rescale=1./255)

test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "CT_Images/Test/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15,
    shuffle=False
)
# Out:
# Found 900 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Predictions

# %%
steps = int(np.ceil(test_df.shape[0] / 15))

predict = model.predict(test_generator, steps=steps)
# Out:
# C:\Users\Binisha\Desktop\ml\env\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 296ms/step

# %%
test_df['predicted category'] = np.argmax(predict, axis=-1)

# %%
test_df['predicted category'] = test_df['predicted category'].replace({ 1: 'Stone', 0: 'Normal' })

# %%
test_df.head()
# Out:
#                     filename category predicted category
# 0  Normal\Normal- (1001).jpg   Normal             Normal
# 1  Normal\Normal- (1002).jpg   Normal             Normal
# 2  Normal\Normal- (1003).jpg   Normal             Normal
# 3  Normal\Normal- (1004).jpg   Normal             Normal
# 4  Normal\Normal- (1005).jpg   Normal             Normal

# %%
plt.figure(figsize=(12, 4))

# Plot the first bar plot (predicted category)
plt.subplot(1, 2, 1)
test_df['predicted category'].value_counts().plot.bar()
plt.title('Predicted Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Plot the second bar plot (actual category)
plt.subplot(1, 2, 2)
test_df['category'].value_counts().plot.bar()
plt.title('Actual Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Assuming 'Stone' is the positive class
print('Precision:', precision_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print('Recall:', recall_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print('F1 Score:', f1_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print(classification_report(test_df['category'], test_df['predicted category']))
# Out:
# Precision: 0.9803921568627451
# Recall: 1.0
# F1 Score: 0.9900990099009901
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      0.99       600
#        Stone       0.98      1.00      0.99       300
#
#     accuracy                           0.99       900
#    macro avg       0.99      0.99      0.99       900
# weighted avg       0.99      0.99      0.99       900

# %%
cm = confusion_matrix(test_df['category'], test_df['predicted category'])

sns.heatmap(cm, annot=True, fmt='d', cmap='BuPu')

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

plt.show()

# %% [markdown]
# The results is baised toward normal as we have more Normal Images

# %%
model.evaluate(test_generator)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9934 - loss: 0.0411
# [0.04865723475813866, 0.9933333396911621]

# %% [markdown]
# # Prediction with user input

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import random

# %%
model = load_model('kidney_stone_detection_CT_image_model_elu.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_image(image_path):
    """
    Predicts if a CT scan image is 'Normal' or 'Stone'.
    
    Parameters:
    - image_path (str): Path to the CT scan image.
    
    Returns:
    - str: 'Normal' or 'Stone' based on the prediction.
    """
    # Load and preprocess the image
    image = load_img(image_path, target_size=(150, 150))  # Resize to match model's input size
    image = img_to_array(image) / 255.0  # Normalize the image
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    
    # Make a prediction
    prediction = model.predict(image)
    print(prediction[0][0])
    if prediction[0][0] > 0.5:
        return 'Kidney Stone Detected (Positive)',round(prediction[0][0]*100,2),'%'
    else:
        return 'No Kidney Stone Detected  (Negative)',round(prediction[0][0]*100,2),'%'

# %%
user_image_path = input("Enter the path to your CT scan image: ")
if os.path.exists(user_image_path):
    result = predict_image(user_image_path)
    print(f"The uploaded CT scan image is classified as: {result}")
else:
    print("File not found. Please check the path and try again.")
