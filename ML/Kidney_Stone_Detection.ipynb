# %% [markdown]
# # Kidney Stone Classication using CT_Images

# %% [markdown]
# ## Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
import random
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import cv2 
from skimage.feature import hog 
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix
# import gradio as gr
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# !pip install keras==3.6.0
# Out:
# Collecting keras==3.6.0
#   Obtaining dependency information for keras==3.6.0 from https://files.pythonhosted.org/packages/c2/88/eef50051a772dcb4433d1f3e4c1d6576ba450fe83e89d028d7e8b85a2122/keras-3.6.0-py3-none-any.whl.metadata
#   Using cached keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (2.1.0)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (1.24.3)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (13.7.0)
# Requirement already satisfied: namex in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.0.8)
# Requirement already satisfied: h5py in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (3.12.1)
# Requirement already satisfied: optree in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.4.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (23.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\dell\anaconda3\lib\site-packages (from optree->keras==3.6.0) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras==3.6.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras==3.6.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.6.0) (0.1.0)
# Using cached keras-3.6.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
# Successfully installed keras-3.6.0

# %%
# !pip install tensorflow

# %% [markdown]
# ## Preparing Traning Data

# %%
folder_path = "./CT_Images/Train"
filenames = []
categories = []

for category in os.listdir(folder_path):
    category_path = os.path.join(folder_path, category)
    
    if os.path.isdir(category_path):
        for filename in os.listdir(category_path):
            filenames.append(os.path.join(category, filename))
            categories.append(category)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#                     filename category
# 0     Normal\Normal- (1).jpg   Normal
# 1    Normal\Normal- (10).jpg   Normal
# 2   Normal\Normal- (100).jpg   Normal
# 3  Normal\Normal- (1000).jpg   Normal
# 4   Normal\Normal- (101).jpg   Normal

# %%
df.tail()
# Out:
#                     filename category
# 2995  Stone\Stone- (995).jpg    Stone
# 2996  Stone\Stone- (996).jpg    Stone
# 2997  Stone\Stone- (997).jpg    Stone
# 2998  Stone\Stone- (998).jpg    Stone
# 2999  Stone\Stone- (999).jpg    Stone

# %%
df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# We have 3000 total images (2000 Normal, 1000 Stone)

# %% [markdown]
# ## Visualizing Data

# %%
sample = random.choice(filenames)
image = load_img("./CT_Images/Train/"+sample)
plt.imshow(image)

# %% [markdown]
# # CNN(Convolutional Neural Network)

# %% [markdown]
# ## Building CNN Model

# %%
model = Sequential()

#Adding convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#Adding a second convolutional layer
model.add(Conv2D(64, (3, 3) , activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())  # this converts our feature maps to 1D feature vectors
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2)) # as we have binary class i.e stone and normal so value is 2
model.add(Activation('sigmoid')) #sigmoid for binary class classification
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 148, 148, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 72, 72, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 82944)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      10,616,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 2)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,637,506 (40.58 MB)
#  Trainable params: 10,637,058 (40.58 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Call Backs

# %% [markdown]
# #### Early Stop
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# #### Learning Rate Reduction
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ### Preparing Data

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Train and Validation generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "./CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15,
    shuffle=True
)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "./CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15
)
# Out:
# Found 2400 validated image filenames belonging to 2 classes.
# Found 600 validated image filenames belonging to 2 classes.

# %%
# Function to yield data from the generator
def generate_data(generator):
    while True:
        yield from generator

# Create TensorFlow datasets with repeat
train_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(train_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 150, 150, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()  # Repeat indefinitely

validation_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(validation_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 150, 150, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()

# %% [markdown]
# ### Visulaizing the output of data gen

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "./CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fitting the Model

# %%
# Compiling the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_dataset, 
    epochs=50,
    validation_data=validation_dataset,
    validation_steps=validate_df.shape[0]//15,
    steps_per_epoch=train_df.shape[0]//15,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 470ms/step - accuracy: 0.6893 - loss: 0.6879 - val_accuracy: 0.3100 - val_loss: 4.3978 - learning_rate: 0.0010
# Epoch 2/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 438ms/step - accuracy: 0.8412 - loss: 0.3991 - val_accuracy: 0.3033 - val_loss: 2.1619 - learning_rate: 0.0010
# Epoch 3/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 478ms/step - accuracy: 0.8558 - loss: 0.3536 - val_accuracy: 0.3567 - val_loss: 1.1937 - learning_rate: 0.0010
# Epoch 4/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 77s 479ms/step - accuracy: 0.8800 - loss: 0.3067 - val_accuracy: 0.9233 - val_loss: 0.1835 - learning_rate: 0.0010
# Epoch 5/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 65s 408ms/step - accuracy: 0.8949 - loss: 0.2700 - val_accuracy: 0.9417 - val_loss: 0.1814 - learning_rate: 0.0010
# Epoch 6/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 470ms/step - accuracy: 0.8792 - loss: 0.3018 - val_accuracy: 0.8483 - val_loss: 0.5770 - learning_rate: 0.0010
# Epoch 7/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8934 - loss: 0.2535
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 431ms/step - accuracy: 0.8934 - loss: 0.2535 - val_accuracy: 0.8083 - val_loss: 0.7652 - learning_rate: 0.0010
# Epoch 8/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 435ms/step - accuracy: 0.9048 - loss: 0.2275 - val_accuracy: 0.9700 - val_loss: 0.0998 - learning_rate: 5.0000e-04
# Epoch 9/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 434ms/step - accuracy: 0.9167 - loss: 0.2120 - val_accuracy: 0.9567 - val_loss: 0.1061 - learning_rate: 5.0000e-04
# Epoch 10/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9312 - loss: 0.1687
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 433ms/step - accuracy: 0.9311 - loss: 0.1689 - val_accuracy: 0.7067 - val_loss: 0.5151 - learning_rate: 5.0000e-04
# Epoch 11/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 467ms/step - accuracy: 0.9187 - loss: 0.2141 - val_accuracy: 0.9767 - val_loss: 0.0802 - learning_rate: 2.5000e-04
# Epoch 12/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 67s 421ms/step - accuracy: 0.9341 - loss: 0.1757 - val_accuracy: 0.9250 - val_loss: 0.1698 - learning_rate: 2.5000e-04
# Epoch 13/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.9277 - loss: 0.1833
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 438ms/step - accuracy: 0.9278 - loss: 0.1832 - val_accuracy: 0.9600 - val_loss: 0.1102 - learning_rate: 2.5000e-04
# Epoch 14/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 436ms/step - accuracy: 0.9273 - loss: 0.1793 - val_accuracy: 0.9167 - val_loss: 0.1774 - learning_rate: 1.2500e-04
# Epoch 15/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9538 - loss: 0.1307
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 436ms/step - accuracy: 0.9538 - loss: 0.1307 - val_accuracy: 0.8883 - val_loss: 0.2195 - learning_rate: 1.2500e-04
# Epoch 16/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 441ms/step - accuracy: 0.9353 - loss: 0.1640 - val_accuracy: 0.9617 - val_loss: 0.1112 - learning_rate: 6.2500e-05
# Epoch 17/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9458 - loss: 0.1425
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 68s 424ms/step - accuracy: 0.9458 - loss: 0.1426 - val_accuracy: 0.9750 - val_loss: 0.0806 - learning_rate: 6.2500e-05
# Epoch 18/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 449ms/step - accuracy: 0.9451 - loss: 0.1502 - val_accuracy: 0.9600 - val_loss: 0.1107 - learning_rate: 3.1250e-05
# Epoch 19/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9376 - loss: 0.1576
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 68s 426ms/step - accuracy: 0.9376 - loss: 0.1574 - val_accuracy: 0.9633 - val_loss: 0.0961 - learning_rate: 3.1250e-05
# Epoch 20/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 459ms/step - accuracy: 0.9491 - loss: 0.1163 - val_accuracy: 0.9683 - val_loss: 0.0894 - learning_rate: 1.5625e-05
# Epoch 21/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9630 - loss: 0.1128
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 443ms/step - accuracy: 0.9629 - loss: 0.1129 - val_accuracy: 0.9683 - val_loss: 0.0859 - learning_rate: 1.5625e-05

# %% [markdown]
# ### Visualizing the Training history

# %%
# Plotting the training history
plt.figure(figsize=(12, 8)) 

# Plot training & validation accuracy values
plt.subplot(2, 1, 1)  # 2 rows, 1 column, first subplot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second subplot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving the CNN Model

# %%
# Saving the Model
model.save('kidney_stone_detection_CT_image_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Testing Data

# %%
test_folder_path = "./CT_Images/Test"
test_filenames = []
test_categories = []

for category in os.listdir(test_folder_path):
    test_category_path = os.path.join(test_folder_path, category)
    
    if os.path.isdir(test_category_path):
        for filename in os.listdir(test_category_path):
            test_filenames.append(os.path.join(category, filename))
            test_categories.append(category)

test_df = pd.DataFrame({
    'filename': test_filenames,
    'category': test_categories
})

# %%
test_gen = ImageDataGenerator(rescale=1./255)

test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "./CT_Images/Test/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15,
    shuffle=False
)
# Out:
# Found 900 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Predictions

# %%
steps = int(np.ceil(test_df.shape[0] / 15))

predict = model.predict(test_generator, steps=steps)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 239ms/step

# %%
test_df['predicted category'] = np.argmax(predict, axis=-1)

# %%
test_df['predicted category'] = test_df['predicted category'].replace({ 1: 'Stone', 0: 'Normal' })

# %%
test_df.head()
# Out:
#                     filename category predicted category
# 0  Normal\Normal- (1001).jpg   Normal             Normal
# 1  Normal\Normal- (1002).jpg   Normal             Normal
# 2  Normal\Normal- (1003).jpg   Normal             Normal
# 3  Normal\Normal- (1004).jpg   Normal             Normal
# 4  Normal\Normal- (1005).jpg   Normal             Normal

# %%
plt.figure(figsize=(12, 4))

# Plot the first bar plot (predicted category)
plt.subplot(1, 2, 1)
test_df['predicted category'].value_counts().plot.bar()
plt.title('Predicted Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Plot the second bar plot (actual category)
plt.subplot(1, 2, 2)
test_df['category'].value_counts().plot.bar()
plt.title('Actual Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
cm = confusion_matrix(test_df['category'], test_df['predicted category'])

sns.heatmap(cm, annot=True, fmt='d', cmap='BuPu')

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

plt.show()

# %% [markdown]
# The results is baised toward normal as we have more Normal Images

# %%
model.evaluate(test_generator)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9820 - loss: 0.0359
# [0.2904500663280487, 0.8722222447395325]

# %% [markdown]
# # Prediction with user input

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import random

# %%
model = load_model('kidney_stone_detection_CT_image_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_image(image_path):
    """
    Predicts if a CT scan image is 'Normal' or 'Stone'.
    
    Parameters:
    - image_path (str): Path to the CT scan image.
    
    Returns:
    - str: 'Normal' or 'Stone' based on the prediction.
    """
    # Load and preprocess the image
    image = load_img(image_path, target_size=(150, 150))  # Resize to match model's input size
    image = img_to_array(image) / 255.0  # Normalize the image
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    
    # Make a prediction
    prediction = model.predict(image)
    print(prediction[0][0])
    if prediction[0][0] > 0.5:
        return 'Kidney Stone Detected (Positive)',round(prediction[0][0]*100,2),'%'
    else:
        return 'No Kidney Stone Detected  (Negative)',round(prediction[0][0]*100,2),'%'

# %%
user_image_path = input("Enter the path to your CT scan image: ")
if os.path.exists(user_image_path):
    result = predict_image(user_image_path)
    print(f"The uploaded CT scan image is classified as: {result}")
else:
    print("File not found. Please check the path and try again.")
# Out:
# Enter the path to your CT scan image: ./Normal- (4611).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 0.25292808
# The uploaded CT scan image is classified as: ('No Kidney Stone Detected  (Negative)', 25.29, '%')
