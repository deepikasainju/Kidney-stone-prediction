# %% [markdown]
# # Kidney Stone Classication using CT_Images

# %% [markdown]
# ## Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
import random
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import cv2 
from skimage.feature import hog 
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix
# import gradio as gr
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# !pip install keras==3.6.0
# Out:
# Collecting keras==3.6.0
#   Obtaining dependency information for keras==3.6.0 from https://files.pythonhosted.org/packages/c2/88/eef50051a772dcb4433d1f3e4c1d6576ba450fe83e89d028d7e8b85a2122/keras-3.6.0-py3-none-any.whl.metadata
#   Using cached keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (2.1.0)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (1.24.3)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (13.7.0)
# Requirement already satisfied: namex in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.0.8)
# Requirement already satisfied: h5py in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (3.12.1)
# Requirement already satisfied: optree in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (0.4.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from keras==3.6.0) (23.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\dell\anaconda3\lib\site-packages (from optree->keras==3.6.0) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras==3.6.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras==3.6.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.6.0) (0.1.0)
# Using cached keras-3.6.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
# Successfully installed keras-3.6.0

# %%
# !pip install tensorflow

# %% [markdown]
# ## Preparing Traning Data

# %%
folder_path = "../../CT scan kidnet stone detection code/CT_Images/Train"
filenames = []
categories = []

for category in os.listdir(folder_path):
    category_path = os.path.join(folder_path, category)
    
    if os.path.isdir(category_path):
        for filename in os.listdir(category_path):
            filenames.append(os.path.join(category, filename))
            categories.append(category)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#                     filename category
# 0     Normal\Normal- (1).jpg   Normal
# 1    Normal\Normal- (10).jpg   Normal
# 2   Normal\Normal- (100).jpg   Normal
# 3  Normal\Normal- (1000).jpg   Normal
# 4   Normal\Normal- (101).jpg   Normal

# %%
df.tail()
# Out:
#                     filename category
# 2995  Stone\Stone- (995).jpg    Stone
# 2996  Stone\Stone- (996).jpg    Stone
# 2997  Stone\Stone- (997).jpg    Stone
# 2998  Stone\Stone- (998).jpg    Stone
# 2999  Stone\Stone- (999).jpg    Stone

# %%
df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# We have 3000 total images (2000 Normal, 1000 Stone)

# %% [markdown]
# ## Visualizing Data

# %%
sample = random.choice(filenames)
image = load_img("../../CT scan kidnet stone detection code/CT_Images/Train/"+sample)
plt.imshow(image)

# %% [markdown]
# # CNN(Convolutional Neural Network)

# %% [markdown]
# ## Building CNN Model

# %%
model = Sequential()

#Adding convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#Adding a second convolutional layer
model.add(Conv2D(64, (3, 3) , activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())  # this converts our feature maps to 1D feature vectors
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2)) # as we have binary class i.e stone and normal so value is 2
model.add(Activation('sigmoid')) #sigmoid for binary class classification
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 148, 148, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 72, 72, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 82944)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      10,616,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 2)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,637,506 (40.58 MB)
#  Trainable params: 10,637,058 (40.58 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Call Backs

# %% [markdown]
# #### Early Stop
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# #### Learning Rate Reduction
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ### Preparing Data

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Train and Validation generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15,
    shuffle=True
)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15
)
# Out:
# Found 2400 validated image filenames belonging to 2 classes.
# Found 600 validated image filenames belonging to 2 classes.

# %%
# Function to yield data from the generator
def generate_data(generator):
    while True:
        yield from generator

# Create TensorFlow datasets with repeat
train_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(train_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 150, 150, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()  # Repeat indefinitely

validation_dataset = tensorflow.data.Dataset.from_generator(
    lambda: generate_data(validation_generator),
    output_signature=(
        tensorflow.TensorSpec(shape=(None, 150, 150, 3), dtype=tensorflow.float32),
        tensorflow.TensorSpec(shape=(None, 2), dtype=tensorflow.float32)
    )
).repeat()

# %% [markdown]
# ### Visulaizing the output of data gen

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Train/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fitting the Model

# %%
# Compiling the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_dataset, 
    epochs=50,
    validation_data=validation_dataset,
    validation_steps=validate_df.shape[0]//15,
    steps_per_epoch=train_df.shape[0]//15,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 77s 462ms/step - accuracy: 0.6977 - loss: 0.7492 - val_accuracy: 0.3133 - val_loss: 2.2774 - learning_rate: 0.0010
# Epoch 2/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 451ms/step - accuracy: 0.8272 - loss: 0.4140 - val_accuracy: 0.5017 - val_loss: 1.6252 - learning_rate: 0.0010
# Epoch 3/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 434ms/step - accuracy: 0.8509 - loss: 0.3571 - val_accuracy: 0.7967 - val_loss: 0.4401 - learning_rate: 0.0010
# Epoch 4/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 475ms/step - accuracy: 0.8902 - loss: 0.2718 - val_accuracy: 0.8817 - val_loss: 0.2554 - learning_rate: 0.0010
# Epoch 5/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 442ms/step - accuracy: 0.8984 - loss: 0.2632 - val_accuracy: 0.6883 - val_loss: 2.3732 - learning_rate: 0.0010
# Epoch 6/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9097 - loss: 0.2306
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 429ms/step - accuracy: 0.9096 - loss: 0.2307 - val_accuracy: 0.8600 - val_loss: 0.4281 - learning_rate: 0.0010
# Epoch 7/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 435ms/step - accuracy: 0.9157 - loss: 0.2261 - val_accuracy: 0.6833 - val_loss: 0.5388 - learning_rate: 5.0000e-04
# Epoch 8/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9147 - loss: 0.2116
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 69s 429ms/step - accuracy: 0.9147 - loss: 0.2116 - val_accuracy: 0.7417 - val_loss: 0.5081 - learning_rate: 5.0000e-04
# Epoch 9/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 450ms/step - accuracy: 0.9407 - loss: 0.1762 - val_accuracy: 0.9733 - val_loss: 0.4838 - learning_rate: 2.5000e-04
# Epoch 10/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 441ms/step - accuracy: 0.9469 - loss: 0.1492 - val_accuracy: 0.8817 - val_loss: 2.7519 - learning_rate: 2.5000e-04
# Epoch 11/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9422 - loss: 0.1453
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 73s 458ms/step - accuracy: 0.9422 - loss: 0.1454 - val_accuracy: 0.9567 - val_loss: 0.1003 - learning_rate: 2.5000e-04
# Epoch 12/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 73s 457ms/step - accuracy: 0.9334 - loss: 0.1671 - val_accuracy: 0.9733 - val_loss: 0.1007 - learning_rate: 1.2500e-04
# Epoch 13/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 451ms/step - accuracy: 0.9491 - loss: 0.1390 - val_accuracy: 0.9750 - val_loss: 0.0875 - learning_rate: 1.2500e-04
# Epoch 14/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 444ms/step - accuracy: 0.9421 - loss: 0.1636 - val_accuracy: 0.9767 - val_loss: 0.0597 - learning_rate: 1.2500e-04
# Epoch 15/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 445ms/step - accuracy: 0.9409 - loss: 0.1537 - val_accuracy: 0.9783 - val_loss: 0.0712 - learning_rate: 1.2500e-04
# Epoch 16/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 485ms/step - accuracy: 0.9619 - loss: 0.1136 - val_accuracy: 0.9817 - val_loss: 0.0570 - learning_rate: 1.2500e-04
# Epoch 17/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 465ms/step - accuracy: 0.9537 - loss: 0.1321 - val_accuracy: 0.9900 - val_loss: 0.0405 - learning_rate: 1.2500e-04
# Epoch 18/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 70s 438ms/step - accuracy: 0.9626 - loss: 0.1108 - val_accuracy: 0.9750 - val_loss: 0.0759 - learning_rate: 1.2500e-04
# Epoch 19/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9583 - loss: 0.1244
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 487ms/step - accuracy: 0.9583 - loss: 0.1245 - val_accuracy: 0.9433 - val_loss: 0.1120 - learning_rate: 1.2500e-04
# Epoch 20/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 473ms/step - accuracy: 0.9601 - loss: 0.1133 - val_accuracy: 1.0000 - val_loss: 0.0259 - learning_rate: 6.2500e-05
# Epoch 21/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 472ms/step - accuracy: 0.9570 - loss: 0.1205 - val_accuracy: 0.9750 - val_loss: 0.0595 - learning_rate: 6.2500e-05
# Epoch 22/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9565 - loss: 0.1150
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 453ms/step - accuracy: 0.9565 - loss: 0.1150 - val_accuracy: 0.9800 - val_loss: 0.0608 - learning_rate: 6.2500e-05
# Epoch 23/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 74s 459ms/step - accuracy: 0.9633 - loss: 0.1044 - val_accuracy: 0.9883 - val_loss: 0.0475 - learning_rate: 3.1250e-05
# Epoch 24/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9489 - loss: 0.1443
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 445ms/step - accuracy: 0.9489 - loss: 0.1442 - val_accuracy: 0.9967 - val_loss: 0.0333 - learning_rate: 3.1250e-05
# Epoch 25/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 73s 454ms/step - accuracy: 0.9586 - loss: 0.1137 - val_accuracy: 0.9933 - val_loss: 0.0330 - learning_rate: 1.5625e-05
# Epoch 26/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9661 - loss: 0.1068
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-05.
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 467ms/step - accuracy: 0.9661 - loss: 0.1068 - val_accuracy: 0.9967 - val_loss: 0.0294 - learning_rate: 1.5625e-05
# Epoch 27/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 73s 457ms/step - accuracy: 0.9687 - loss: 0.0967 - val_accuracy: 0.9967 - val_loss: 0.0281 - learning_rate: 1.0000e-05
# Epoch 28/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 83s 521ms/step - accuracy: 0.9695 - loss: 0.0905 - val_accuracy: 0.9950 - val_loss: 0.0321 - learning_rate: 1.0000e-05
# Epoch 29/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 466ms/step - accuracy: 0.9580 - loss: 0.1156 - val_accuracy: 0.9967 - val_loss: 0.0321 - learning_rate: 1.0000e-05
# Epoch 30/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 444ms/step - accuracy: 0.9650 - loss: 0.0933 - val_accuracy: 0.9967 - val_loss: 0.0252 - learning_rate: 1.0000e-05
# Epoch 31/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 445ms/step - accuracy: 0.9700 - loss: 0.0892 - val_accuracy: 0.9933 - val_loss: 0.0368 - learning_rate: 1.0000e-05
# Epoch 32/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 78s 489ms/step - accuracy: 0.9502 - loss: 0.1351 - val_accuracy: 0.9917 - val_loss: 0.0387 - learning_rate: 1.0000e-05
# Epoch 33/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 450ms/step - accuracy: 0.9717 - loss: 0.0919 - val_accuracy: 0.9900 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 34/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 75s 469ms/step - accuracy: 0.9612 - loss: 0.1028 - val_accuracy: 0.9933 - val_loss: 0.0382 - learning_rate: 1.0000e-05
# Epoch 35/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 72s 452ms/step - accuracy: 0.9571 - loss: 0.1107 - val_accuracy: 0.9917 - val_loss: 0.0369 - learning_rate: 1.0000e-05
# Epoch 36/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 68s 423ms/step - accuracy: 0.9617 - loss: 0.1000 - val_accuracy: 0.9867 - val_loss: 0.0458 - learning_rate: 1.0000e-05
# Epoch 37/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 71s 446ms/step - accuracy: 0.9691 - loss: 0.0983 - val_accuracy: 0.9883 - val_loss: 0.0410 - learning_rate: 1.0000e-05
# Epoch 38/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 76s 473ms/step - accuracy: 0.9568 - loss: 0.1084 - val_accuracy: 0.9883 - val_loss: 0.0440 - learning_rate: 1.0000e-05
# Epoch 39/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 73s 458ms/step - accuracy: 0.9744 - loss: 0.0786 - val_accuracy: 0.9817 - val_loss: 0.0539 - learning_rate: 1.0000e-05
# Epoch 40/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 77s 484ms/step - accuracy: 0.9527 - loss: 0.1210 - val_accuracy: 0.9733 - val_loss: 0.0585 - learning_rate: 1.0000e-05

# %% [markdown]
# ### Visualizing the Training history

# %%
# Plotting the training history
plt.figure(figsize=(12, 8)) 

# Plot training & validation accuracy values
plt.subplot(2, 1, 1)  # 2 rows, 1 column, first subplot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second subplot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving the CNN Model

# %%
# Saving the Model
model.save('kidney_stone_detection_CT_image_model_150.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Testing Data

# %%
test_folder_path = "../../CT scan kidnet stone detection code/CT_Images/Test"
test_filenames = []
test_categories = []

for category in os.listdir(test_folder_path):
    test_category_path = os.path.join(test_folder_path, category)
    
    if os.path.isdir(test_category_path):
        for filename in os.listdir(test_category_path):
            test_filenames.append(os.path.join(category, filename))
            test_categories.append(category)

test_df = pd.DataFrame({
    'filename': test_filenames,
    'category': test_categories
})

# %%
test_gen = ImageDataGenerator(rescale=1./255)

test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "../../CT scan kidnet stone detection code/CT_Images/Test/", 
    x_col='filename',
    y_col='category',
    target_size=(150,150),
    class_mode='categorical',
    batch_size=15,
    shuffle=False
)
# Out:
# Found 900 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Predictions

# %%
steps = int(np.ceil(test_df.shape[0] / 15))

predict = model.predict(test_generator, steps=steps)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 149ms/step

# %%
test_df['predicted category'] = np.argmax(predict, axis=-1)

# %%
test_df['predicted category'] = test_df['predicted category'].replace({ 1: 'Stone', 0: 'Normal' })

# %%
test_df.head()
# Out:
#                     filename category predicted category
# 0  Normal\Normal- (1001).jpg   Normal             Normal
# 1  Normal\Normal- (1002).jpg   Normal             Normal
# 2  Normal\Normal- (1003).jpg   Normal             Normal
# 3  Normal\Normal- (1004).jpg   Normal             Normal
# 4  Normal\Normal- (1005).jpg   Normal             Normal

# %%
plt.figure(figsize=(12, 4))

# Plot the first bar plot (predicted category)
plt.subplot(1, 2, 1)
test_df['predicted category'].value_counts().plot.bar()
plt.title('Predicted Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Plot the second bar plot (actual category)
plt.subplot(1, 2, 2)
test_df['category'].value_counts().plot.bar()
plt.title('Actual Categories')
plt.xlabel('Category')
plt.ylabel('Count')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Assuming 'Stone' is the positive class
print('Precision:', precision_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print('Recall:', recall_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print('F1 Score:', f1_score(test_df['category'], test_df['predicted category'], pos_label='Stone'))
print(classification_report(test_df['category'], test_df['predicted category']))
# Out:
# Precision: 0.8105590062111802
# Recall: 0.87
# F1 Score: 0.8392282958199357
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.90      0.92       600
#        Stone       0.81      0.87      0.84       300
#
#     accuracy                           0.89       900
#    macro avg       0.87      0.88      0.88       900
# weighted avg       0.89      0.89      0.89       900

# %%
cm = confusion_matrix(test_df['category'], test_df['predicted category'])

sns.heatmap(cm, annot=True, fmt='d', cmap='BuPu')

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

plt.show()

# %% [markdown]
# The results is baised toward normal as we have more Normal Images

# %%
model.evaluate(test_generator)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9382 - loss: 0.2027
# [0.3476542830467224, 0.8888888955116272]

# %% [markdown]
# # Prediction with user input

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import random

# %%
model = load_model('kidney_stone_detection_CT_image_model_150.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_image(image_path):
    """
    Predicts if a CT scan image is 'Normal' or 'Stone'.
    
    Parameters:
    - image_path (str): Path to the CT scan image.
    
    Returns:
    - str: 'Normal' or 'Stone' based on the prediction.
    """
    # Load and preprocess the image
    image = load_img(image_path, target_size=(150, 150))  # Resize to match model's input size
    image = img_to_array(image) / 255.0  # Normalize the image
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    
    # Make a prediction
    prediction = model.predict(image)
    print(prediction[0][0])
    if prediction[0][0] > 0.5:
        return 'Kidney Stone Detected (Positive)',round(prediction[0][0]*100,2),'%'
    else:
        return 'No Kidney Stone Detected  (Negative)',round(prediction[0][0]*100,2),'%'

# %%
user_image_path = input("Enter the path to your CT scan image: ")
if os.path.exists(user_image_path):
    result = predict_image(user_image_path)
    print(f"The uploaded CT scan image is classified as: {result}")
else:
    print("File not found. Please check the path and try again.")
# Out:
# Enter the path to your CT scan image: ./Normal- (4611).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 0.25292808
# The uploaded CT scan image is classified as: ('No Kidney Stone Detected  (Negative)', 25.29, '%')
